# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data/day_ahead_1s.csv", index_col ="time")
df
# Out:
#                            power_kW  energy_Wh
# time
# 2026-01-26 00:00:00+07:00       0.0   0.000000
# 2026-01-26 00:00:01+07:00       0.0   0.000000
# 2026-01-26 00:00:02+07:00       0.0   0.000000
# 2026-01-26 00:00:03+07:00       0.0   0.000000
# 2026-01-26 00:00:04+07:00       0.0   0.000000
# ...                             ...        ...
# 2026-01-26 23:59:55+07:00       0.0  35.529846
# 2026-01-26 23:59:56+07:00       0.0  35.529846
# 2026-01-26 23:59:57+07:00       0.0  35.529846
# 2026-01-26 23:59:58+07:00       0.0  35.529846
# 2026-01-26 23:59:59+07:00       0.0  35.529846
#
# [86400 rows x 2 columns]

# %%
plt.plot(df["power_kW"].values)
